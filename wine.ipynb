# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
url='/content/wine.csv'
data=pd.read_csv(url)
data.head()
data.hist()
plt.show()

# %%
sns.pairplot(data)

# %%
correlation=data.corr()
print(correlation)
# Out:
#               1     14.23      1.71      2.43      15.6       127       2.8  \
# 1      1.000000 -0.321238  0.436127 -0.048260  0.513963 -0.198944 -0.717933
# 14.23 -0.321238  1.000000  0.099963  0.210964 -0.303350  0.258742  0.284543
# 1.71   0.436127  0.099963  1.000000  0.164955  0.286148 -0.049049 -0.333512
# 2.43  -0.048260  0.210964  0.164955  1.000000  0.446698  0.287107  0.128176
# 15.6   0.513963 -0.303350  0.286148  0.446698  1.000000 -0.071707 -0.317583
# 127   -0.198944  0.258742 -0.049049  0.287107 -0.071707  1.000000  0.208200
# 2.8   -0.717933  0.284543 -0.333512  0.128176 -0.317583  0.208200  1.000000
# 3.06  -0.846485  0.230133 -0.409324  0.114084 -0.346922  0.187101  0.864046
# .28    0.487215 -0.151445  0.291501  0.187354  0.359395 -0.252091 -0.448301
# 2.29  -0.494887  0.127561 -0.217975  0.008082 -0.190779  0.226504  0.610533
# 5.64   0.268562  0.547883  0.250053  0.258643  0.020478  0.199337 -0.056401
# ...

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter', x='1', y='3.06',figsize=(9,9),color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='1', ylabel='3.06'>

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['1']), y=data['3.06'])
print('gia tri intercept:', model.intercept_)
print('gia tri coefficent:', model.coef_)
print('do chinh xac:', model.score(X=pd.DataFrame(data['1']), y=data['3.06']))
# Out:
# gia tri intercept: 4.146129032258065
# gia tri coefficent: [-1.0921943]
# do chinh xac: 0.7165373364084549

# %%
data.plot(kind='scatter', x='1', y='3.06',figsize=(9,9),color='black',xlim=(0,7))
y_pred=model.predict(X=pd.DataFrame(data['1']))
plt.plot(data['1'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['1'], data['3.06']**2]).T
model.fit(X,y=data['3.06'])
print('gia tri intercept:', model.intercept_)
print('gia tri coefficent:', model.coef_)
print('do chinh xac:', model.score(X,y=data['1']))
#mpg=-13,38*wt+1,17wt^2_49,93
# Out:
# gia tri intercept: 1.7177450198467623
# gia tri coefficent: [-0.32402249  0.18392385]
# do chinh xac: -3.799303851407614

# %%
range=np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=X_range)
data.plot(kind='scatter', x='1', y='3.06',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
model.fit(X=data.loc[:,['1','3.92']],y=data['3.06'])
print('gia tri intercept:', model.intercept_)
print('gia tri coefficent:', model.coef_)
print('do chinh xac:', model.score(X=data.loc[:,['1','3.92']],y=data['3.06']))
#mpg=-3,87wt-0,03hp+37,22
# Out:
# gia tri intercept: 2.355763101651168
# gia tri coefficent: [-0.77125908  0.44796306]
# do chinh xac: 0.7547042076118604
