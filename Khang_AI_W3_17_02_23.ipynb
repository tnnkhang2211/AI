# %%
import pandas as pd 
dataframe=pd.DataFrame()
dataframe['Name']=['lemon','lime','banana']
dataframe['price']=[5,6,7]
dataframe['lisence']=[False, True, True]
dataframe
# Out:
#      Name  price  lisence
# 0   lemon      5    False
# 1    lime      6     True
# 2  banana      7     True

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df=dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   price    3 non-null      int64
#  2   lisence  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
list(df.columns)
# Out:
# ['Name', 'price', 'lisence']

# %%
df.describe()
# Out:
#        price
# count    3.0
# mean     6.0
# std      1.0
# min      5.0
# 25%      5.5
# 50%      6.0
# 75%      6.5
# max      7.0

# %%
df.loc[(df.price == 5)]
# Out:
#     Name  price  lisence
# 0  lemon      5    False

# %%
df.loc[(df.price == 5) |(df.Name == 'banana') ]
# Out:
#      Name  price  lisence
# 0   lemon      5    False
# 2  banana      7     True

# %%
df.loc[(df.price == 5) |(df.Name == 'banana'), ('Name','price') ]
# Out:
#      Name  price
# 0   lemon      5
# 2  banana      7

# %%
df.loc[(df.price ==5) | (df.Name =='lemon'), ('Name')]
# Out:
# 0    lemon
# Name: Name, dtype: object

# %%
df.iloc[0:2]
# Out:
#     Name  price  lisence
# 0  lemon      5    False
# 1   lime      6     True

# %%
df.iloc[0:2,0:-1]
# Out:
#     Name  price
# 0  lemon      5
# 1   lime      6

# %%
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: lisence, dtype: bool

# %%
sum=df.price.sum()
sum
# Out:
# 18

# %%
new=pd.Series(['orange',10,True], index=['Name','price', 'license'])
df.append(new, ignore_index=True)
# Out:
#      Name  price  lisence  license
# 0   lemon      5      0.0      NaN
# 1    lime      6      1.0      NaN
# 2  banana      7      1.0      NaN
# 3  orange     10      NaN      1.0

# %%
dataframe['location']=['USA','VN','SIN']
df
# Out:
#      Name  price  lisence location
# 0   lemon      5    False      USA
# 1    lime      6     True       VN
# 2  banana      7     True      SIN

# %%
#delete a column
dataframe.drop(1, axis=0).head()
# Out:
#      Name  price  lisence location
# 0   lemon      5    False      USA
# 2  banana      7     True      SIN

# %%
dataframe.drop('location', axis=1).head()
# Out:
#      Name  price  lisence
# 0   lemon      5    False
# 1    lime      6     True
# 2  banana      7     True

# %%
dataframe['price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    6
# 2    7
# Name: price, dtype: int64

# %%
df.rename(columns={'price':'Cost'}).head(3)
# Out:
#      Name  Cost  lisence location
# 0   lemon     5    False      USA
# 1    lime     6     True       VN
# 2  banana     7     True      SIN

# %%
url='/medals.csv'

# %%
dataframe=pd.read_csv(url)

# %%
dataframe
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
dataframe.shape
# Out:
# (2311, 8)

# %%
dataframe['Year'].unique()
# Out:
# array([1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972,
#        1976, 1980, 1984, 1988, 1992, 1994, 1998, 2002, 2006])

# %%
dataframe.describe()
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
dataframe[(dataframe['Year']>=1990)&(dataframe['Year']<=2006) & (dataframe['NOC']=='USA')&(dataframe['Event gender']=='W')&(dataframe['Medal']=='Gold')].head(10)
# Out:
#       Year         City       Sport      Discipline  NOC       Event  \
# 1428  1992  Albertville     Skating  Figure skating  USA  individual
# 1430  1992  Albertville     Skating  Short Track S.  USA        500m
# 1431  1992  Albertville     Skating   Speed skating  USA       1000m
# 1432  1992  Albertville     Skating   Speed skating  USA        500m
# 1436  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# 1610  1994  Lillehammer     Skating  Short Track S.  USA        500m
# 1612  1994  Lillehammer     Skating   Speed skating  USA       1000m
# 1613  1994  Lillehammer     Skating   Speed skating  USA        500m
# 1617  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# 1812  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
#
#      Event gender Medal
# 1428            W  Gold
# 1430            W  Gold
# 1431            W  Gold
# 1432            W  Gold
# 1436            W  Gold
# 1610            W  Gold
# 1612            W  Gold
# ...

# %%
dataframe['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
dataframe.count()
# Out:
# Year            2311
# City            2311
# Sport           2311
# Discipline      2311
# NOC             2311
# Event           2311
# Event gender    2311
# Medal           2311
# dtype: int64
